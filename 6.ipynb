# %%
import numpy as np
import matplotlib.pyplot as plt

modelos = ["Árbol", "Bosque", "k-NN", "Weighted k-NN"]
acc_val_mean = [0.94, 0.98, 0.86, 0.83]
acc_val_std  = [0.02, 0.011, 0.01, 0.025]
acc_test     = [0.96, 0.98, 0.88, 0.82]

x = np.arange(len(modelos))
width = 0.35  # ancho de las barras

plt.figure(figsize=(8,5))
plt.bar(x - width/2, acc_val_mean, width, yerr=acc_val_std, capsize=4, label="Validación", color="#B0B969")
plt.bar(x + width/2, acc_test, width, label="Test", color="#003732")

plt.ylabel("Accuracy")
#plt.title("Comparación de modelos")
plt.xticks(x, modelos)
plt.ylim(0.7, 1.0)
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Otra forma

plt.figure(figsize=(8,5))
plt.errorbar(modelos, acc_val_mean, yerr=acc_val_std, fmt='-o', capsize=4, label="Validación")
plt.plot(modelos, acc_test, '-s', label="Test")

plt.ylabel("Accuracy")
plt.title("Curvas de desempeño de modelos")
plt.ylim(0.7, 1.0)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# 7. Conclusiones finales
#
# El clasificador que elegiríamos para implementar en una aplicación real es el Random Forest. Este modelo presenta el mejor rendimiento tanto en validación como en test, alcanzando una precisión cercana al 98% y mostrando además una baja variabilidad, lo que indica una buena capacidad de generalización. En comparación, el Árbol de decisión individual logra también un desempeño alto, aunque con mayor dispersión en los resultados, lo que lo hace más sensible a variaciones en los datos. Los métodos k-NN y Weighted k-NN, en cambio, exhiben una precisión notablemente menor, en torno al 82 y 88%, lo que los vuelve menos confiables. Esperaríamos que el Random Forest mantenga una precisión superior al 95% en una aplicación práctica, con un buen equilibrio entre robustez, interpretabilidad relativa y capacidad de manejar datos complejos sin sobreajustarse.
